# %% [markdown]
# ###  in this code we are replacing the 1 value (means true) by its real crop id for each crop file

# %%
from pathlib import Path

#in this folder , each file contains one type of crop and its name is the name of the crop 
#we faced this problem because we changed the export strategy
#here we exported each crop in a separate file instead of exporting all the crops in one file 
#instead of randomly exporting samples in one file
#because not every crop has the same number across these 2 states.
dossier = Path('../data_fix')

for fichier in dossier.iterdir():
    if fichier.is_file(): 
        print(fichier.name)

# %%
import pandas as pd
from pathlib import Path


dossier_source = Path('../data_fix')

# keywords are matched in the filename to determine the correct code to apply
mapping_codes = {
    'Soybeans': 1,
    'Corn': 5,
    'Rice': 3,
    'Cotton': 2,
    'Grapes': 69,
    'Almonds': 75,
    'Alfalfa': 36,
    'Pistachio': 76,  
    'Others': 176,
    'Grass': 176      
}

def fix_labels_in_folder():
    fichiers = list(dossier_source.glob('*.csv'))
    print(f"🚀 Début de la correction sur {len(fichiers)} fichiers...")

    for f in fichiers:
       
        code_a_appliquer = None
        nom_fichier = f.name
        
        for keyword, code in mapping_codes.items():
            if keyword in nom_fichier:
                code_a_appliquer = code
                break
        
        if code_a_appliquer is None:
            print(f"⚠️  Impossible de déterminer le code pour : {nom_fichier}")
            continue

        try:
            df = pd.read_csv(f)
            
            if 'cropland' in df.columns:
               
                df['cropland'] = code_a_appliquer
                
                
                df.to_csv(f, index=False)
                print(f"✅ Corrigé : {nom_fichier} -> ID {code_a_appliquer}")
            else:
                print(f"❓ Colonne 'cropland' absente dans : {nom_fichier}")
                
        except Exception as e:
            print(f"❌ Erreur sur {nom_fichier} : {e}")

if __name__ == "__main__":
    fix_labels_in_folder()
    print("\n✨ Traitement terminé. Tous tes '1' sont maintenant des ID CDL corrects.")
# Out:
# 🚀 Début de la correction sur 83 fichiers...
# ✅ Corrigé : Arkansas_Soybeans_boost4.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Soybeans_Seed123.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Others_Grass_Seed999.csv -> ID 176
# ✅ Corrigé : MCTNet_BOOST_Soybeans_101_AR.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost6.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Almonds_Seed42.csv -> ID 75
# ✅ Corrigé : MCTNet_California_Almonds_500.csv -> ID 75
# ✅ Corrigé : MCTNet_California_Others_Grass_Seed777.csv -> ID 176
# ✅ Corrigé : MCTNet_BOOST_Soybeans_100_AR.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Cotton_Seed2024.csv -> ID 2
# ✅ Corrigé : Arkansas_Soybeans_boost2.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Others_Grass_400.csv -> ID 176
# ✅ Corrigé : Arkansas_Soybeans_boost14.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Cotton_Seed42.csv -> ID 2
# ✅ Corrigé : MCTNet_Arkansas_Corn_Seed123.csv -> ID 5
# ✅ Corrigé : MCTNet_Arkansas_Others_Grass_Seed2024.csv -> ID 176
# ✅ Corrigé : MCTNet_California_Rice_Seed999.csv -> ID 3
# ✅ Corrigé : MCTNet_Arkansas_Rice_Seed42.csv -> ID 3
# ✅ Corrigé : MCTNet_Arkansas_Soybeans_Seed2024.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost3.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Corn_Seed2024.csv -> ID 5
# ✅ Corrigé : Arkansas_Soybeans_boost16.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Rice_Seed2024.csv -> ID 3
# ✅ Corrigé : PATCH_Arkansas_Rice_Patch.csv -> ID 3
# ✅ Corrigé : MCTNet_California_Alfalfa_Seed42.csv -> ID 36
# ✅ Corrigé : Arkansas_Soybeans_boost8.csv -> ID 1
# ✅ Corrigé : MCTNet_BOOST_Soybeans_102_AR.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost23.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost15.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Alfalfa_Seed2024.csv -> ID 36
# ✅ Corrigé : PATCH_California_Rice_Patch.csv -> ID 3
# ✅ Corrigé : PATCH_California_Grapes_Patch.csv -> ID 69
# ✅ Corrigé : MCTNet_California_Almonds_Seed777.csv -> ID 75
# ✅ Corrigé : MCTNet_California_Others_Grass_Seed2024.csv -> ID 176
# ✅ Corrigé : PATCH_California_Pistachios_Patch.csv -> ID 76
# ✅ Corrigé : MCTNet_Arkansas_Others_Grass_Seed42.csv -> ID 176
# ✅ Corrigé : MCTNet_California_Pistachios_Seed2024.csv -> ID 76
# ✅ Corrigé : MCTNet_California_Rice_Seed777.csv -> ID 3
# ✅ Corrigé : Arkansas_Soybeans_boost19.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Grapes_Seed42.csv -> ID 69
# ✅ Corrigé : MCTNet_California_Rice_Seed2024.csv -> ID 3
# ✅ Corrigé : Arkansas_Soybeans_boost18.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost1.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Almonds_Seed123.csv -> ID 75
# ✅ Corrigé : MCTNet_California_Rice_Seed42.csv -> ID 3
# ✅ Corrigé : MCTNet_Arkansas_Others_Grass_Seed123.csv -> ID 176
# ✅ Corrigé : MCTNet_California_Rice_1800.csv -> ID 3
# ✅ Corrigé : Arkansas_Soybeans_boost13.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost17.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Cotton_Seed123.csv -> ID 2
# ✅ Corrigé : Arkansas_Soybeans_boost25.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost22.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Pistachios_Seed777.csv -> ID 76
# ✅ Corrigé : MCTNet_California_Grapes_Seed123.csv -> ID 69
# ✅ Corrigé : MCTNet_Arkansas_Others_Grass_Seed777.csv -> ID 176
# ✅ Corrigé : Arkansas_Soybeans_boost21.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Grapes_1800.csv -> ID 69
# ✅ Corrigé : MCTNet_California_Alfalfa_700.csv -> ID 36
# ✅ Corrigé : MCTNet_California_Pistachio_Boost.csv -> ID 76
# ✅ Corrigé : Arkansas_Soybeans_boost12.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Cotton_Seed999.csv -> ID 2
# ✅ Corrigé : Arkansas_Soybeans_boost5.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Corn_Seed999.csv -> ID 5
# ✅ Corrigé : PATCH_California_Alfalfa_Patch.csv -> ID 36
# ✅ Corrigé : MCTNet_Arkansas_Rice_2200.csv -> ID 3
# ✅ Corrigé : MCTNet_California_Alfalfa_Seed123.csv -> ID 36
# ✅ Corrigé : MCTNet_California_Pistachios_Seed123.csv -> ID 76
# ✅ Corrigé : MCTNet_Arkansas_Cotton_500.csv -> ID 2
# ✅ Corrigé : MCTNet_California_Alfalfa_Seed777.csv -> ID 36
# ✅ Corrigé : Arkansas_Soybeans_boost7.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost10.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Corn_Seed777.csv -> ID 5
# ✅ Corrigé : MCTNet_California_Almonds_Seed2024.csv -> ID 75
# ✅ Corrigé : MCTNet_BOOST_Soybeans_103_Arkansas.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Cotton_Seed777.csv -> ID 2
# ✅ Corrigé : Arkansas_Soybeans_boost11.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost24.csv -> ID 1
# ✅ Corrigé : MCTNet_California_Pistachios_Seed42.csv -> ID 76
# ✅ Corrigé : MCTNet_California_Rice_Seed123.csv -> ID 3
# ✅ Corrigé : MCTNet_Arkansas_Rice_Seed777.csv -> ID 3
# ✅ Corrigé : Arkansas_Soybeans_boost9.csv -> ID 1
# ✅ Corrigé : Arkansas_Soybeans_boost20.csv -> ID 1
# ✅ Corrigé : MCTNet_Arkansas_Corn_1300.csv -> ID 5
#
# ✨ Traitement terminé. Tous tes '1' sont maintenant des ID CDL corrects.

# %% [markdown]
# #### after this we move the files to the ```datasets``` folder to get fused and concat with the other files.
